# %%
api_key = 'LhEvgrgZLKCqij8TJUx_'
import Quandl
mydata = Quandl.get("FRED/GDP",  authtoken=api_key)

# %%
Quandl.get("NVCA/VENTURE_3_08", authtoken="LhEvgrgZLKCqij8TJUx_")
# Out:
#              AK/HI/PR   Colorado  DC/Metroplex  LA/Orange County    Midwest  \
# Date
# 1985-12-31   758.8000   435.4000      221.2000          196.5000   157.5000
# 1986-12-31  1016.3000   436.6000      211.0000          186.9000   139.9000
# 1987-12-31   849.9000   525.1000      273.9000          276.9000   198.4000
# 1988-12-31   985.9000   496.9000      308.0000          222.5000   132.3000
# 1989-12-31   916.5000   404.7000      360.4000          242.1000   183.2000
# 1990-12-31   914.1000   425.0000      190.1000          174.7000   155.9000
# 1991-12-31   780.5000   287.0000      181.5000          119.4000   181.4000
# 1992-12-31  1119.5000   417.0000      239.0000          179.4000   165.2000
# 1993-12-31   903.2000   358.4000      222.3000          176.4000   276.9000
# 1994-12-31  1074.4000   440.4000      283.3000          198.4000   432.6000
# 1995-12-31     7.7600   325.0535      415.1680         1004.0980   470.4157
# ...
